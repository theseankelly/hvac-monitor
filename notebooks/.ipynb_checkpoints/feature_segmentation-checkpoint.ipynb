# %%
import numpy as np
import cv2

from scipy import stats

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
#im = cv2.imread('../data/sports.jpg')
#im = cv2.imread('../data/lightson.jpg', flags=cv2.IMREAD_COLOR)
#im = cv2.imread('../data/allon.jpg', flags=cv2.IMREAD_COLOR)
#im = cv2.imread('../data/allon_lightson.jpg')

# zones 1 and 3 on
im = cv2.imread('../data/dump/hvac/statechange/2019-02-23_05-29-25.jpg.jpg')

# %%
plt.imshow(im)

# %%
#
# Crop an ROI -- hardcode for now!
#
im_roi = im[230:280,670:700]
plt.imshow(im_roi)

# %%
led_centroids = np.array(
    [[7,12],
     [13,12],
     [13,19],
     [20,12],
     [20,19],
     [26,12],
     [26,19],
     [33,12],
     [33,19]])
plt.imshow(im_roi)
plt.scatter(led_centroids[:,1], led_centroids[:,0])

# %%
im_hsv = cv2.cvtColor(im_roi, cv2.COLOR_BGR2HSV)

plt.imshow(im_hsv[:,:,2])

# %%
## im_roi_gray = cv2.cvtColor(im_roi, cv2.COLOR_BGR2GRAY)
plt.imshow(im_roi_gray)

# %%
plt.imshow(im_roi_gray > 80)

# %%
b = cv2.GaussianBlur(im_roi_gray, (3,3), 3, 3)

plt.subplot(2,2,1)
plt.imshow(b)

c = cv2.addWeighted(b, 3, b, 0, 0)
plt.subplot(2,2,2)
plt.imshow(c)

mask = c > 128
plt.subplot(2,2,3)
plt.imshow(mask)

# %%
led_centroids()

# %%
plt.imshow(total_mask)

# %%
total_mask = mask.astype(np.uint8)
plt.imshow(total_mask)

# %%
params = cv2.SimpleBlobDetector_Params()
params.minThreshold = 0
params.maxThreshold = 400
params.minDistBetweenBlobs = 1
params.filterByArea = False
params.minArea = 0
params.maxArea = 25
params.filterByCircularity = False
params.filterByConvexity = False
params.filterByInertia = False
params.filterByColor = False

detector = cv2.SimpleBlobDetector_create(params)
keypoints = detector.detect((total_mask.astype(np.uint8)))

im_with_keypoints = cv2.drawKeypoints(total_mask, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(im_with_keypoints)

# %%
pts = np.asarray([[p.pt[1], p.pt[0]] for p in keypoints])
pts

len(pts)
# Out:
# 1

# %%
np.sort(pts, axis=0)
# Out:
# array([[11.88888931, 14.22222233],
#        [28.92592621, 19.62962914]])
